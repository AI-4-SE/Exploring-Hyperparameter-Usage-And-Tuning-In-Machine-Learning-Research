# %%
import glob
import json
from collections import Counter
import pandas as pd

ALL_SKLEARN_PROJECTS = "statistics/sklearn/statistics/*"
ALL_TENSORFLOW_PROJECTS = "statistics/tensorflow/statistics/*"
ALL_PYTORCH_PROJECTS = "statistics/pytorch/statistics/*"
TEST_PROJECT = "statistics/sklearn/statistics/statistics_100DaysofMLCodeChallenge.json"

# %% [markdown]
# Calculate number of modules of all sklearn projects

# %%
all_modules = []
modules_without_options = []

for project in glob.glob(ALL_SKLEARN_PROJECTS):
    with open(project, "r", encoding="utf-8") as project_file:
        project_data = json.load(project_file)

        for file in project_data:
            file_data = project_data[file]
            for module in file_data:
                module_name = module.split("_")[0]
                #print("Name:", module_name)
                all_modules.append(module_name)
                module_data = file_data[module]
                #print("Data:", module_data)
                if not module_data:
                    modules_without_options.append(module_name)

df_all = pd.DataFrame.from_dict(Counter(all_modules), orient="index", columns=["total_number"]).reindex()
df_without_option = pd.DataFrame.from_dict(Counter(modules_without_options), orient="index", columns=["without_options"]).reindex()

result = df_all.join(df_without_option)
result["without_options"] = result['without_options'].fillna(0).astype(int)
result = result.sort_values(by=['total_number'], ascending=False)
result
# Out:
#                            total_number  without_options
# StandardScaler                       29               28
# MinMaxScaler                         19               10
# KMeans                               19                0
# LabelEncoder                         10               10
# KFold                                 7                0
# NearestNeighbors                      6                0
# LinearRegression                      6                6
# OneHotEncoder                         5                0
# TfidfVectorizer                       5                1
# TSNE                                  5                0
# StratifiedKFold                       5                0
# SVC                                   5                0
# LogisticRegression                    5                0
# LinearSVC                             4                3
# CountVectorizer                       4                1
# KernelDensity                         3                0
# GaussianNB                            2                2
# LeaveOneGroupOut                      2                2
# GaussianMixture                       2                0
# Lasso                                 2                0
# GroupKFold                            2                0
# LatentDirichletAllocation             2                0
# KNeighborsClassifier                  2                0
# HuberRegressor                        2                0
# AgglomerativeClustering               2                0
# RandomForestClassifier                2                0
# RandomForestRegressor                 2                0
# PCA                                   2                0
# GridSearchCV                          2                0
# MLPClassifier                         2                0
# MeanShift                             1                0
# MultiLabelBinarizer                   1                1
# TruncatedSVD                          1                0
# GaussianProcessRegressor              1                0
# PolynomialFeatures                    1                0
# DBSCAN                                1                0
# BayesianGaussianMixture               1                0
# DecisionTreeRegressor                 1                0
# Ridge                                 1                0
# KernelPCA                             1                0
# KDTree                                1                0
# LabelBinarizer                        1                1
# ParameterSampler                      1                0
# MaxAbsScaler                          1                1
# SVR                                   1                0
# DecisionTreeClassifier                1                0

# %%
df = result[result["total_number"] == result["without_options"]]
df
# Out:
#                      total_number  without_options
# LabelEncoder                   10               10
# LinearRegression                6                6
# GaussianNB                      2                2
# LeaveOneGroupOut                2                2
# MultiLabelBinarizer             1                1
# LabelBinarizer                  1                1
# MaxAbsScaler                    1                1
